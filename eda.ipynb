# %%
import pandas as pd 
import matplotlib.pyplot as plt
df = pd.read_csv("data/anime_dataset.csv")
print(df)
# Out:
#        mal_id                            title            title_english  \
# 0           1                     Cowboy Bebop             Cowboy Bebop
# 1           5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2           6                           Trigun                   Trigun
# 3           7               Witch Hunter Robin       Witch Hunter Robin
# 4           8                   Bouken Ou Beet   Beet the Vandel Buster
# ...       ...                              ...                      ...
# 30070   64004                     Manzoku desu                      NaN
# 30071   64005                          Overlay                      NaN
# 30072   64006     Megane, Tokidoki, Yankee-kun                      NaN
# 30073   64012                  The Ribbon Hero          The Ribbon Hero
# 30074   64012                  The Ribbon Hero          The Ribbon Hero
#
#                          title_japanese   type    source  episodes  \
# ...

# %%
df.shape
# Out:
# (30075, 29)

# %%
df.columns
# Out:
# Index(['mal_id', 'title', 'title_english', 'title_japanese', 'type', 'source',
#        'episodes', 'status', 'airing', 'aired_from', 'aired_to', 'duration',
#        'rating', 'score', 'scored_by', 'rank', 'popularity', 'members',
#        'favorites', 'season', 'year', 'studios', 'producers', 'licensors',
#        'genres', 'themes', 'demographics', 'synopsis', 'image_url'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# mal_id                0
# title                 0
# title_english     16769
# title_japanese      124
# type                 72
# source                0
# episodes            839
# status                0
# airing                0
# aired_from          909
# aired_to          18481
# duration              0
# rating              602
# score             10183
# scored_by         10183
# rank               7491
# popularity            0
# members               0
# favorites             0
# season            23550
# year              23550
# studios           11938
# producers         15796
# licensors         24877
# genres             6394
# themes            12098
# demographics      18941
# synopsis           5038
# image_url             0
# dtype: int64

# %%
genres_top10 = df[["genres"]].value_counts()
print(genres_top10.head(10))
# Out:
# genres
# Comedy                      3069
# Fantasy                     1504
# Hentai                      1325
# Slice of Life                938
# Drama                        854
# Avant Garde                  836
# Sci-Fi                       775
# Action|Adventure|Fantasy     733
# Adventure|Fantasy            623
# Comedy|Fantasy               575
# Name: count, dtype: int64

# %%
plt.hist(df[["score"]], bins = 30)
plt.title("Distribution of Anime Score ")
plt.xlabel("Score")
plt.ylabel("Peoples")
plt.show()

# %%
plt.scatter(df[["score"]], df[["rank"]])
plt.xlabel("score")
plt.ylabel("rank")
plt.show()

# %%
plt.boxplot(df[["favorites"]])
plt.show()
